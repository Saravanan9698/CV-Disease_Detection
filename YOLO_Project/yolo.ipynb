# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.chdir("D:/Projects/Disease_Detection/YOLO_Project/yolov5")

# %%
print("Current Directory: ", os.getcwd())
# Out:
# Current Directory:  D:\Projects\Disease_Detection\YOLO_Project\yolov5

# %%
! python detect.py --source "D:\Projects\Disease_Detection\YOLO_Project\images\val" --weights yolov5s.pt
# Out:
# detect: weights=['yolov5s.pt'], source=D:\Projects\Disease_Detection\YOLO_Project\images\val, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-411-gf4d8a84c Python-3.12.9 torch-2.6.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/164 D:\Projects\Disease_Detection\YOLO_Project\images\val\00000261_002.png: 640x640 1 person, 453.3ms
# image 2/164 D:\Projects\Disease_Detection\YOLO_Project\images\val\00000273_002.png: 640x640 (no detections), 293.1ms
# ...

# %%
! python segment/predict.py --img 640 --conf 0.5 --source "D:\Projects\Disease_Detection\YOLO_Project\images\val" --weights yolov5s-seg.pt
# Out:
# segment\predict: weights=['yolov5s-seg.pt'], source=D:\Projects\Disease_Detection\YOLO_Project\images\val, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5  v7.0-411-gf4d8a84c Python-3.12.9 torch-2.6.0+cpu CPU
#
# ...
#
#   0%|          | 0.00/14.9M [00:00<?, ?B/s]
#   1%|          | 128k/14.9M [00:00<00:33, 468kB/s]
#   3%|▎         | 512k/14.9M [00:00<00:09, 1.51MB/s]
#   5%|▌         | 768k/14.9M [00:00<00:08, 1.78MB/s]
#   7%|▋         | 1.00M/14.9M [00:00<00:08, 1.78MB/s]
#   8%|▊         | 1.25M/14.9M [00:00<00:07, 1.85MB/s]
#  10%|█         | 1.50M/14.9M [00:01<00:08, 1.57MB/s]
# ...

# %%
! python train.py --img 416 --batch 8 --epochs 10 --data "D:\Projects\Disease_Detection\YOLO_Project\yolov5\data.yaml" --weights yolov5s.pt
# Out:
# ^C
